# %%
import numpy as np
import pandas as pd
import io
from google.colab import files
uploade=files.upload()
uploadex=files.upload()
dk=pd.read_excel(io.BytesIO(uploade['AYP+2016-17+to+2018-19+Yields(PC)+ (1).xlsx']))
dkk=pd.read_excel(io.BytesIO(uploadex['2018-19 yield.xlsx']))
# Out:
#      <input type="file" id="files-ec7907ff-11b1-41bf-81bc-a7b43cba42d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec7907ff-11b1-41bf-81bc-a7b43cba42d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AYP+2016-17+to+2018-19+Yields(PC)+ (1).xlsx to AYP+2016-17+to+2018-19+Yields(PC)+ (1) (1).xlsx
#      <input type="file" id="files-49858a39-b8af-416c-896a-51cce2bb94bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49858a39-b8af-416c-896a-51cce2bb94bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ...

# %%
ddss=dkk.iloc[0:50]
name=input()
Di=dk['Unnamed: 1']==name

tc=dk[Di].reset_index().iloc[0][0]

x=tc
j=0
a=[]
b=[]
while(x<300):

  ddi=dk.iloc[x]['Unnamed: 4']
  a.append(ddi)
  j+=1
  x+=36

x+=1
while(x>300 and x<623):
  ddi=dk.iloc[x]['Unnamed: 4']
  b.append(ddi)
  x+=36

for i in range(0,len(b)):
  a.append(b[i])
import matplotlib.pyplot as plt

yy=np.array(a)
myylabels = ["RICE","MAIZE","GREEN GRAM","BLACKGRAM","REDGRAM","BENGALGRAM","COWGRAM","CHILLIES","TURMERIC","SUGARCANE","ONIONS","COTTON CAPAS","COTTON LINT","GROUNDNUT","GINGELLY","SOYABEAN","CASTER"]

plt.pie(yy,labels = myylabels,radius=3)
plt.show() 
print("\t\t\t\t2016-2017")



dii=dkk['Unnamed: 1']==name

tcc=dkk[dii].reset_index().iloc[0][0]

xx=tcc
jj=0
aa=[]
bb=[]
while(xx<280):

  ddii=dkk.iloc[xx]['Unnamed: 4']
  aa.append(ddii)
  jj+=1
  xx+=38

xx+=1
while(xx>300 and xx<650):
  ddii=dkk.iloc[xx]['Unnamed: 4']
  bb.append(ddii)
  xx+=36

for i in range(0,len(bb)):
  aa.append(bb[i])

dkk[dii]
helloo=pd.DataFrame({'CROP 2017-2018':["RICE","MAIZE","GREEN GRAM","BLACKGRAM","REDGRAM","BENGALGRAM","COWGRAM","CHILLIES","TURMERIC","SUGARCANE","ONIONS","COTTON CAPAS","COTTON LINT","GROUNDNUT","GINGELLY","SOYABEAN","CASTER"],'TOTAL YEILD':a})
bxx= helloo.plot.bar(x='CROP 2017-2018', y='TOTAL YEILD', rot=0)
print("\n")
yyy=np.array(aa)
myyylabels = ["RICE","MAIZE","GREEN GRAM","BLACKGRAM","REDGRAM","BENGALGRAM","COWGRAM","CHILLIES","TURMERIC","SUGARCANE","ONIONS","COTTON CAPAS","COTTON LINT","GROUNDNUT","GINGELLY","SOYABEAN","CASTER"]

plt.pie(yyy,labels = myyylabels,radius=3)
plt.show()
# Out:
# KHAMMAM
# 				2016-2017
